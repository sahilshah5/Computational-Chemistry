# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

# %%
absA=np.loadtxt('Absorption_Alice', skiprows=1, unpack=True)
absB=np.loadtxt('Absorption_Bob', skiprows=1, unpack=True)
fluA=np.loadtxt('Fluorescence_Alice', skiprows=1, unpack=True)
fluB=np.loadtxt('Fluorescence_Bob', skiprows=1, unpack=True)

# %%
plot(absA[0], absA[1])
plot(absB[0],absB[1])

# %%
plot(fluA[0], fluA[1])
plot(fluB[0],fluB[1])

# %%
transient_data=np.loadtxt('Transient-Absorption_2D-DATA.mx3', unpack=True)

# %%
transient_data
# Out:
# array([[  0.00000000e+00,   4.50000000e+02,   4.55000000e+02, ...,
#           9.40000000e+02,   9.45000000e+02,   9.50000000e+02],
#        [ -2.50000000e+00,  -1.02420319e-05,  -2.90735137e-06, ...,
#          -5.29027700e-06,   2.65971816e-05,  -2.43185169e-05],
#        [ -2.49700000e+00,  -7.90105144e-05,  -1.05426039e-06, ...,
#           2.55985665e-05,  -9.34980519e-06,  -4.16879803e-05],
#        ...,
#        [  1.99940000e+01,   5.68455200e-05,   5.58399084e-05, ...,
#          -1.04595061e-04,  -5.33965613e-05,  -3.70907191e-05],
#        [  1.99970000e+01,   2.44293897e-05,   6.92552453e-05, ...,
#          -7.62748700e-05,  -1.43604208e-05,  -2.22200837e-05],
#        [  2.00000000e+01,  -6.02364360e-05,   2.11499710e-05, ...,
#          -8.78704498e-05,  -8.49543935e-05,  -7.14324700e-05]])
