# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x8 = np.loadtxt('8x8.dat')
T8= x8[:,0]
E8=x8[:,1]
var8= x8[:,2] - x8[:,1]**2
C8=var8/((T8)**2)
plt.plot(T8, C8)
xlabel('Temperature')
ylabel('Heat Capacity')
# Out:
# Text(0, 0.5, 'Heat Capacity')

# %%
x2 = np.loadtxt('2x2.dat')
T2= x2[:,0]
E2=x2[:,1]
var2= x2[:,2] - x2[:,1]**2
C2=var2/((T2)**2)
plt.plot(T2, C2)
xlabel('Temperature')
ylabel('Heat Capacity')
# Out:
# Text(0, 0.5, 'Heat Capacity')

# %%
x4 = np.loadtxt('4x4.dat')
T4= x4[:,0]
E4=x4[:,1]
var4= x4[:,2] - x4[:,1]**2
C4=var4/((T4)**2)
plt.plot(T4, C4)
xlabel('Temperature')
ylabel('Heat Capacity')
# Out:
# Text(0, 0.5, 'Heat Capacity')

# %%
x16 = np.loadtxt('16x16.dat')
T16= x16[:,0]
E16=x16[:,1]
var16= x16[:,2] - x16[:,1]**2
C16=var16/((T16)**2)
plt.plot(T16, C16)
xlabel('Temperature')
ylabel('Heat Capacity')
# Out:
# Text(0, 0.5, 'Heat Capacity')

# %%
x32 = np.loadtxt('32x32.dat')
T32= x32[:,0]
E32=x32[:,1]
var32= x32[:,2] - x32[:,1]**2
C32=var32/((T32)**2)
plt.plot(T32, C32)
xlabel('Temperature')
ylabel('Heat Capacity')
# Out:
# Text(0, 0.5, 'Heat Capacity')
